# %% [markdown]
# ## BASIC IMPORTS

# %%
from TBAC  import StockScrub                      #This line tells python to import the class. Class file should be in same directory as code file
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Creating Instance of StockScrub Class

# %%
ss=StockScrub(['AAPL','AA','XOM'])

# %% [markdown]
# ### Gathering Data for Selected Stocks and Viewing The First Few Rows; Try/Except on KeyError has been Integrated

# %%
df=ss.get_data()
df
# Out:
#                      close       volume
# symbol date
# AAPL   2019-03-29  46.5799  167838582.0
#        2019-04-05  48.3087  111540445.0
#        2019-04-12  48.7673  132006698.0
#        2019-04-18  49.9909   96335577.0
#        2019-04-26  50.0988   97495453.0
#        2019-05-03  51.9257  186455669.0
#        2019-05-10  48.5417  173663634.0
#        2019-05-17  46.5279  186415472.0
#        2019-05-24  44.0587  156970116.0
#        2019-05-31  43.0986  104691321.0
#        2019-06-07  46.8110  154348161.0
#        2019-06-14  47.4486  111843021.0
#        2019-06-21  48.9356  131658960.0
#        2019-06-28  48.7238  117368626.0
#        2019-07-05  50.2772   72879519.0
#        2019-07-12  50.0483  101600835.0
#        2019-07-19  49.8735   87433154.0
#        2019-07-26  51.1413   87153118.0
#        2019-08-02  50.2255  219770512.0
#        2019-08-09  49.6692  173211425.0
#        2019-08-16  51.0308  163266105.0
#        2019-08-23  50.0769  142066853.0
# ...

# %% [markdown]
# ### Getting Data For a Specific Company

# %%
df.loc['XOM']
# Out:
#               close       volume
# date
# 2019-03-29  72.1856   46353797.0
# 2019-04-05  73.6954   46445353.0
# 2019-04-12  72.2928   53748295.0
# 2019-04-18  72.4804   33347098.0
# 2019-04-26  71.9086   62238190.0
# 2019-05-03  69.2106   65196061.0
# 2019-05-10  69.1749   62496411.0
# 2019-05-17  68.5876   49027739.0
# 2019-05-24  66.9522   45216831.0
# 2019-05-31  63.9434   51903558.0
# 2019-06-07  67.3859   53706489.0
# 2019-06-14  67.1781   42658888.0
# 2019-06-21  70.1959   68542433.0
# 2019-06-28  69.2381   54046783.0
# 2019-07-05  68.7864   34056399.0
# 2019-07-12  70.1417   36359985.0
# 2019-07-19  67.7563   47402001.0
# 2019-07-26  67.5937   41942932.0
# 2019-08-02  64.8289   65667235.0
# 2019-08-09  64.0066   74585002.0
# 2019-08-16  62.4827   66086207.0
# 2019-08-23  61.7417   54258513.0
# 2019-08-30  62.6474   44671070.0
# 2019-09-06  64.8887   37128079.0
# 2019-09-13  66.4531   53181858.0
# 2019-09-20  65.9408   70007961.0
# 2019-09-27  65.3919   46828363.0
# ...

# %% [markdown]
# ### Plotting Time Series of Closing Prices for Specific Company

# %%
df.loc['AAPL'].close.plot(title="Time Series of Adjusted Closing Prices for Apple")
# Out:
# <AxesSubplot:title={'center':'Time Series of Adjusted Closing Prices for Apple'}, xlabel='date'>
