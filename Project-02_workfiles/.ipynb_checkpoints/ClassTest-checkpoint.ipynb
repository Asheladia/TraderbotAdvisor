# %% [markdown]
# ## BASIC IMPORTS

# %%
from TBAC  import StockScrub, VIX_update                      #This line tells python to import the class.
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np                     
from dotenv import load_dotenv 
# %matplotlib inline
#!pip install newspaper3k                                     
from GoogleNews import GoogleNews
from newspaper import Article
from datetime import datetime
import numpy as np

# %% [markdown]
# ### Creating Objects of the StockScrub Class

# %%
apple=StockScrub(['AAPL'])

# %% [markdown]
# ### Pulls in most recent available data AlphaVantage API for a single ticker representing permitted stock or cryptocurrency

# %%
#apple.get_data()
# Out:
# Data successfully stored.

# %% [markdown]
# ### Pulls in most recent available data on VIX indicator from Quandl API to be used for analysis

# %%
#VIX_update()
# Out:
# Data successfully stored.

# %% [markdown]
# # Preliminary Results of Getting Sentiment for Specified Stock
# ### *(Don't have articles for each day,presents a challenge for gathering sentiment. Either improve search query or consider all sources and remove days that don't have news)*
# ### -Takes news from GoogleNews API, combines news on same day and removes duplicated days
# ### -tokenizes content for sentiment computation
# ### -The contents column will be the column that contains the sentiment scores

# %%
apple.get_sentiment()
# Out:
#                                                          site  \
# 2020-06-22                                     apple newsroom
# 2020-07-21                                     apple newsroom
# 2020-08-04                                     apple newsroom
# 2020-08-13                            raleigh news & observer
# 2020-08-31                                               cnbc
# 2020-09-15                                     apple newsroom
# 2020-09-16                                     apple newsroom
# 2020-09-17                                     apple newsroom
# 2020-10-13                                     apple newsroom
# 2020-10-23                                     apple newsroom
# 2020-10-30                                          macrumors
# 2020-11-05                                     apple newsroom
# 2020-11-10                                     apple newsroom
# 2020-11-12                                     apple newsroom
# 2020-11-18                                     apple newsroom
# 2020-11-24                                     apple newsroom
# 2020-12-01                                     apple newsroom
# 2020-12-08                               apple newsroom, cnet
# 2020-12-13                                         zdnet, cnn
# 2020-12-14                            apple newsroom, 9to5mac
# 2020-12-15                               the verge, thestreet
# 2020-12-16  apple newsroom, the verge, macrumors, investor...
# 2020-12-17                                     cnbc, nbc news
# 2020-12-18                 techradar, macrumors, the guardian
# 2020-12-19                                          the verge
# 2020-12-20                                        how-to geek
# 2020-12-21                                       the guardian
# 2020-12-22             teslarati, bloomberg, 9to5mac, reuters
# 2020-12-23                             inc., vox.com, 9to5mac
# 2020-12-26                                           engadget
# 2020-12-29                                the washington post
# 2020-12-30                  honolulu star-advertiser, 9to5mac
# 2021-01-01                                   business insider
# 2021-01-05                                 macrumors, 9to5mac
# 2021-01-06                                          macrumors
# 2021-01-07                              mac rumors, macrumors
# 2021-01-08       appleinsider, macrumors, ocregister, 9to5mac
# 2021-01-09  9to5mac, appleinsider, the guardian, business ...
# 2021-01-10  infoq.com, ocregister, voice of america, zdnet...
#
#                                                       content
# 2020-06-22  [APPLE, INTRODUCES, MACOS, BIG, SUR, WITH, A, ...
# 2020-07-21  [APPLE, COMMITS, TO, BE, PERCENT, CARBON, NEUT...
# 2020-08-04  [INCH, IMAC, GETS, A, MAJOR, UPDATE, APPLE, TO...
# 2020-08-13  [EPIC, GAMES, FILES, LAWSUIT, AGAINST, APPLE, ...
# 2020-08-31  [HISTORY, OF, APPLE, STOCK, SPLITS, SAYS, INVE...
# 2020-09-15  [APPLE, ONE, MAKES, ENJOYING, APPLE, SUBSCRIPT...
# 2020-09-16  [IOS, IS, AVAILABLE, TODAY, IOS, REIMAGINES, T...
# 2020-09-17  [APPLE, BRINGS, ONLINE, STORE, TO, INDIA, SEPT...
# 2020-10-13  [APPLE, ANNOUNCES, IPHONE, AND, IPHONE, MINI, ...
# 2020-10-23  [IPHONE, IPHONE, PRO, AND, IPAD, AIR, ARE, HER...
# 2020-10-30  [APPLE, ONE, WHAT, YOU, NEED, TO, KNOW, APPLE,...
# 2020-11-05  [IPHONE, PRO, MAX, IPHONE, MINI, AND, HOMEPOD,...
# 2020-11-10  [APPLE, UNLEASHES, M, APPLE, TODAY, ANNOUNCED,...
# 2020-11-12  [MACOS, BIG, SUR, IS, HERE, UPDATE, BRINGS, A,...
# 2020-11-18  [APPLE, ANNOUNCES, APP, STORE, SMALL, BUSINESS...
# 2020-11-24  [DEVELOPERS, SAY, APP, STORE, SMALL, BUSINESS,...
# 2020-12-01  [APPLE, PRESENTS, APP, STORE, BEST, OF, WINNER...
# 2020-12-08  [PRESS, RELEASE, APPLE, INTRODUCES, AIRPODS, M...
# 2020-12-13  [I, WENT, TO, AN, APPLE, STORE, TO, BUY, A, NE...
# 2020-12-14  [APPLE, FITNESS, THE, NEXT, ERA, OF, FITNESS, ...
# 2020-12-15  [A, SHOW, ABOUT, GAWKER, PROVED, TOO, HOT, FOR...
# 2020-12-16  [A, LANDMARK, YEAR, OF, GIVING, FROM, APPLE, H...
# 2020-12-17  [FACEBOOK, CRITICIZES, APPLE, AS, IT, WELCOMES...
# 2020-12-18  [HOW, TO, GET, APPLE, FITNESS, PLUS, FIND, OUT...
# 2020-12-19  [APPLE, JUST, TEMPORARILY, CLOSED, ALL, STORES...
# 2020-12-20  [HOW, TO, CREATE, DATE, AND, TIME, COMPLICATIO...
# 2020-12-21  [APPLE, AIRPODS, MAX, REVIEW, STUNNING, SOUND,...
# 2020-12-22  [TESLA, APPROACHED, APPLE, WHEN, IT, WAS, MOST...
# 2020-12-23  [FACEBOOK, DECLARED, WAR, ON, APPLE, AND, IT, ...
# 2020-12-26  [HOW, TO, MAKE, THE, MOST, OF, YOUR, NEW, APPL...
# 2020-12-29  [APPLE, LOSES, COPYRIGHT, BATTLE, AGAINST, SEC...
# 2020-12-30  [APPLE, HITS, RECORD, AFTER, DECEMBER, SURGE, ...
# 2021-01-01  [THE, APPLE, WATCH, SE, WAS, MY, BEST, PURCHAS...
# 2021-01-05  [APP, STORE, SPENDING, REACHED, BILLION, IN, S...
# 2021-01-06  [APPLE, HIGHLIGHTS, SERVICES, IN, AS, APP, STO...
# 2021-01-07  [APPLE, LAUNCHES, SPECIAL, EDITION, OXTHEMED, ...
# 2021-01-08  [DONT, LET, THIRD, PARTIES, CONFUSE, YOU, ABOU...
# 2021-01-09  [TOREWARDS, LAST, CHANCE, TO, WIN, APPLES, M, ...
# 2021-01-10  [RUST, RELEASED, WITH, TIER, SUPPORT, OF, BIT,...

# %% [markdown]
# ###  Gathering Data for a Specific Company and Time Range: Use Default Time Range or Specify Date. NAs rows incurred from beta computations are removedd

# %%
AAPL_df=apple.data_compile()
AAPL_df.head(30)
# Out:
#                 close      volume    VIX      beta
# 2019-04-22  50.155231  19439545.0  14.15  0.067815
# 2019-04-23  50.878635  23322991.0  14.15  0.373867
# 2019-04-24  50.800164  17540609.0  14.60  0.551584
# 2019-04-25  50.339147  18543206.0  14.90  0.646474
# 2019-04-26  50.098830  18649102.0  14.40  0.483868
# 2019-04-29  50.174848  22204716.0  14.50  0.443627
# 2019-04-30  49.208674  46534923.0  14.40  0.473518
# 2019-05-01  51.624110  64827328.0  15.38 -1.658684
# 2019-05-02  51.288156  31996324.0  15.10 -1.533350
# 2019-05-03  51.925733  20892378.0  14.25 -0.914839
# 2019-05-06  51.123857  32443113.0  16.19 -0.474727
# 2019-05-07  49.745710  38763698.0  17.90  0.624748
# 2019-05-08  49.755519  26339504.0  18.25  0.629330
# 2019-05-09  49.220935  34908607.0  18.10  0.728435
# 2019-05-10  48.541671  41208712.0  16.15  0.598401
# 2019-05-13  45.720454  57430623.0  19.41  1.435853
# 2019-05-14  46.444221  36529677.0  17.91  1.457267
# 2019-05-15  47.000587  26544718.0  16.91  1.499018
# 2019-05-16  46.793796  33031364.0  15.59  1.378216
# 2019-05-17  46.527922  32879090.0  16.02  1.403637
# 2019-05-20  45.073002  38612290.0  16.02  1.468420
# 2019-05-21  45.937092  28364848.0  15.05  1.582593
# 2019-05-22  44.996686  29748556.0  16.22  1.884496
# 2019-05-23  44.228606  36529736.0  17.35  1.804760
# 2019-05-24  44.058742  23714686.0  16.92  1.795617
# 2019-05-28  43.876569  27948160.0  17.37  1.724225
# 2019-05-29  43.667317  28481165.0  17.80  1.755360
# 2019-05-30  43.893802  21218412.0  17.41  1.773759
# 2019-05-31  43.098642  27043584.0  18.20  1.692999
# 2019-06-03  42.662905  40396069.0  18.26  1.784560

# %%
pfe=StockScrub(['PFE'])
PFE_df=pfe.data_compile(start='2016-01-01')
PFE_df.head()
# Out:
#            symbol      close      volume  VIX close
# date
# 2016-01-04    PFE  25.119792  37306299.0      19.80
# 2016-01-05    PFE  25.300623  27302655.0      19.45
# 2016-01-06    PFE  24.852476  25845908.0      20.34
# 2016-01-07    PFE  24.687370  37205401.0      23.54
# 2016-01-08    PFE  24.372881  33053066.0      25.25

# %% [markdown]
# ### Plotting Time Series of Closing Prices for Specific Company

# %%
BTC_df['close'].plot(title='Closing Prices of BTC: USD Market')
# Out:
# <AxesSubplot:title={'center':'Closing Prices of BTC: USD Market'}, xlabel='date'>

# %% [markdown]
# ### Function Calls Close Price and select indicator values of stock. Additional Indicators can be built into the class

# %%
df=apple.get_indicators()

# %%
df.RSI.plot(title="Plot of RSI for Apple Stock; Period of 10")

# %% [markdown]
# ### Modifications to Sentiment Code (In progress)

# %%
#Code used for extracting articles


#for i in range(2,20):
#    googlenews.getpage(i)
#    result=googlenews.result(sort=True)
#    df=pd.DataFrame(result)
        
# while article_day_max=np.sum(df['date']!="")<30:
    #run this code

#googlenews=GoogleNews(start='05/01/2020',end='05/31/2020')
#googlenews.search('Coronavirus')
#result=googlenews.result()
#df=pd.DataFrame(result)
#df.head()                                                                                              # printing the DataFrame       
#df.drop(columns=['img','date'],inplace=True)                                                           # these columns are not needed
#df.set_index('datetime')                                                                               # make datetime the index
#df=data_clean(df)      or df.dropna(axis=0)                                                            # removing NA values

#df.dropna(axis=0).sort_index(ascending=True).drop(columns=['date','img']).set_index('datetime')        # single command that does this
#df.index=df.index.values.apply(lambda DATE: datetime.strptime(DATE,"%Y-%m-%d"))                        # converts index entries to datetime objects


#for ind in df.index:                                                                                   # loops through index to collect information
#    master_dictionary.                                                                                 # initializes dictionary to store data
#    try:
#        article = Article(df['link'][ind])                                                             # stores link of article 
#        article.download()                                                                             # extracts file from article
#        article.parse()                                                                                # parses file from article
#        article.nlp()                                                                                  # interprets file from article ?
#        D['Date']=df['date'][ind]
#        D['Media']=df['media'][ind]
#        D['Title']=article.title
#        D['Article']=article.text
#        D['Summary']=article.summary
#        print(D)
#    except:                                                                       # skips over forbidden urls
#        pass
#news_df=pd.DataFrame(L)
#news_df

# %% [markdown]
# ### Getting Average Beta Values for Specific Stock over a specified period; the default period is 15

# %%
beta_df=apple.get_beta()
beta_df
# Out:
#                 beta
# Date
# 2019-03-29       NaN
# 2019-04-01       NaN
# 2019-04-02       NaN
# 2019-04-03       NaN
# 2019-04-04       NaN
# 2019-04-05       NaN
# 2019-04-08       NaN
# 2019-04-09       NaN
# 2019-04-10       NaN
# 2019-04-11       NaN
# 2019-04-12       NaN
# 2019-04-15       NaN
# 2019-04-16       NaN
# 2019-04-17       NaN
# 2019-04-18       NaN
# 2019-04-22  0.067815
# 2019-04-23  0.373867
# 2019-04-24  0.551584
# 2019-04-25  0.646474
# 2019-04-26  0.483868
# 2019-04-29  0.443627
# 2019-04-30  0.473518
# 2019-05-01 -1.658684
# 2019-05-02 -1.533350
# 2019-05-03 -0.914839
# 2019-05-06 -0.474727
# 2019-05-07  0.624748
# 2019-05-08  0.629330
# 2019-05-09  0.728435
# 2019-05-10  0.598401
# ...              ...
# 2020-11-25  0.794201
# 2020-11-27  0.437060
# 2020-11-30  0.283312
# 2020-12-01  0.723579
# 2020-12-02  0.709339
# 2020-12-03  0.589988
# 2020-12-04  0.552753
# 2020-12-07  0.591192
# 2020-12-08  0.588899
# 2020-12-09  0.748597
# 2020-12-10  0.613603
# 2020-12-11  0.645167
# 2020-12-14  0.568983
# 2020-12-15  1.380152
# 2020-12-16  1.854473
# 2020-12-17  1.820945
# 2020-12-18  1.953905
# 2020-12-21  2.093834
# 2020-12-22  1.774796
# 2020-12-23  1.779050
# 2020-12-24  1.752881
# 2020-12-28  2.567771
# 2020-12-29  2.731206
# 2020-12-30  2.736074
# 2020-12-31  2.271410
# 2021-01-04  2.150041
# 2021-01-05  2.080184
# 2021-01-06  1.798534
# 2021-01-07  1.502831
# 2021-01-08  1.509068
#
# [450 rows x 1 columns]
